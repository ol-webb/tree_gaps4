# %%
import os
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import recall_score, make_scorer
import json

feature_directory = 'local_saved_datasets/feature_datasets/'
timeseries_directory = 'local_saved_datasets/timeseries_datasets/'

dataframe_names = [
    'X_df_2yr', 'X_df_2yr_frost','X_df_2yr_lee',
    'X_df_2yr_temporal_frost','X_df_2yr_temporal',
    'X_df_2yr_temporal_lee','X_df_2yr_quegan',
    'X_df_2yr_quegan_frost','X_df_2yr_quegan3d'
]

feature_dataframes_list = []
for name in dataframe_names:
    filepath = os.path.join(feature_directory, f"{name}.csv")
    df = pd.read_csv(filepath)
    feature_dataframes_list.append(df)

# %%
feature_dataframes_list[0].drop(columns=['gap','area'],axis=1)
# Out:
#      centre_mean  centre_variance  centre_skewness  centre_max  centre_min  \
# 0      -9.305420         2.623679         0.235407   -5.335450  -12.493728
# 1      -7.360199         2.884374        -0.005704   -3.460812  -11.501527
# 2      -6.674077         2.977544         0.338980   -2.749259   -9.790607
# 3      -9.216908         2.696442         0.167488   -5.335450  -12.493728
# 4      -8.843634         2.281068        -0.328632   -5.545258  -12.183754
# ..           ...              ...              ...         ...         ...
# 423    -7.718275         4.462162        -0.365597   -3.374702  -12.235884
# 424    -9.131668         3.875554        -0.349461   -5.245484  -13.690917
# 425    -8.124894         2.407084        -0.031482   -4.569686  -11.779159
# 426    -7.683848         3.131299        -0.847433   -4.861586  -13.761679
# 427    -8.325084         2.513565         0.146140   -4.131106  -11.426734
#
#      centre_range  above_mean  above_variance  above_skewness  above_max  ...  \
# 0        7.158278   -8.226039        2.568873        0.797901  -3.461185  ...
# 1        8.040715   -7.572881        3.715064        0.286721  -2.498692  ...
# 2        7.041348   -6.582725        3.264722       -0.210330  -2.927046  ...
# 3        7.158278   -8.270897        3.168680        0.412550  -3.461185  ...
# 4        6.638496   -9.146630        2.471502        0.392213  -5.362180  ...
# ..            ...         ...             ...             ...        ...  ...
# 423      8.861181   -7.681419        3.578046        0.205955  -1.903831  ...
# 424      8.445433   -7.940684        3.253175       -0.023433  -3.591325  ...
# 425      7.209473   -8.755116        3.347103        0.009426  -5.334141  ...
# 426      8.900092   -7.035547        3.180945       -0.598836  -4.428035  ...
# 427      7.295628   -9.002738        2.995717       -0.393796  -5.652398  ...
#
#      bottom_left_skewness  bottom_left_max  bottom_left_min  \
# 0               -0.694390        -5.309410       -15.360332
# 1               -0.267068        -3.325161       -11.405836
# 2               -0.173504        -3.361433       -11.453809
# 3               -0.749546        -4.894164       -15.360332
# 4               -0.555556        -4.166550       -13.761968
# ..                    ...              ...              ...
# 423             -0.731315        -3.862567       -13.639785
# 424              0.037551        -5.595215       -12.552617
# 425             -0.866109        -3.793895       -13.349059
# 426             -0.305816        -1.782779       -11.456271
# 427             -0.212524        -2.507029       -10.904060
#
#      bottom_left_range  bottom_right_mean  bottom_right_variance  \
# 0            10.050922          -9.627538               4.374496
# 1             8.080675          -8.599813               4.047043
# 2             8.092376          -6.928494               3.168914
# 3            10.466168          -9.820503               4.170402
# 4             9.595418          -8.559150               2.111145
# ..                 ...                ...                    ...
# 423           9.777218          -7.077026               3.611827
# 424           6.957402          -8.941364               3.571031
# 425           9.555164          -7.802899               2.401527
# 426           9.673491          -9.101775               2.574745
# 427           8.397030          -7.745895               2.903050
#
#      bottom_right_skewness  bottom_right_max  bottom_right_min  \
# 0                -0.119734         -6.034732        -14.138251
# 1                -0.349757         -3.506923        -15.360332
# 2                 0.011051         -2.461649        -11.079000
# 3                -0.251802         -6.350979        -14.604690
# 4                 0.028322         -4.839749        -12.683997
# ..                     ...               ...               ...
# 423               0.003079         -2.986453        -11.425755
# 424               0.263672         -3.171384        -13.268400
# 425              -0.492251         -5.078269        -11.689106
# 426               0.147589         -5.546500        -12.552617
# 427               0.279160         -2.772479        -11.787336
#
#      bottom_right_range
# 0              8.103519
# 1             11.853409
# 2              8.617350
# 3              8.253711
# 4              7.844248
# ..                  ...
# 423            8.439302
# 424           10.097016
# 425            6.610837
# 426            7.006117
# 427            9.014857
#
# [428 rows x 54 columns]

# %%
pp2='\\local_saved_datasets\\feature_datasets\\X_df_2yr.csv'

# %%
pd.read_csv(pp2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pd.read_csv(pp2)
#
# File c:\Users\olive\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\olive\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\olive\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\olive\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\olive\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\local_saved_datasets\\feature_datasets\\X_df_2yr.csv'
